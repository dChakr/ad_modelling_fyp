# %% [markdown]
# # Extracting Functional Connectivity Matrix from Empirical Data
#
# Following Nilearn tutorial found at: https://nilearn.github.io/stable/auto_examples/03_connectivity/plot_signal_extraction.html#sphx-glr-auto-examples-03-connectivity-plot-signal-extraction-py

# %%
import pandas as pd
import numpy as np 
import json

from nilearn import plotting
from nilearn import image

from nilearn.connectome import ConnectivityMeasure
from nilearn.maskers import NiftiLabelsMasker
from nilearn.interfaces.fmriprep import load_confounds, load_confounds_strategy
# Out:
# /var/folders/kc/0zmcgk1j313586f5z7yvtgjh0000gn/T/ipykernel_35333/4041282856.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Atlas Data
SCHAEFER_ATLAS_PATH_100 = '../../data/atlases/Schaefer2018_100Parcels_7Networks_order_FSLMNI152_2mm.nii.gz'
SCHAEFER_ATLAS_PATH_116 = '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz'
SCHAEFER_100_LABELS = '../../data/atlases/schaefer100NodeNames.txt'
TIAN_S1_3T_Labels = '../../data/atlases/Tian_Subcortex_S1_3T_label.txt'

# FMRI Data
FMRI_FILE_PATH = "../../data/adni/sub-ADNI002S0295/ses-M060/func/sub-ADNI002S0295_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz"
FMRI_FILE_PATH_POST_PROCESSED = '../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S2073_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz'
CONFOUNDS_FILE_PATH = "../../data/adni/sub-ADNI002S0295/ses-M060/func/sub-ADNI002S0295_ses-M060_task-rest_desc-confounds_timeseries.tsv"

# %%
# Retrieve Schaefer Atlas
from nilearn import datasets 
from nilearn.image import resample_to_img
from nilearn.datasets import load_mni152_template

# # Load the background image
# background_img = load_mni152_template()

# # Load and resample the atlas to match the resolution of the background image
# atlas_img = resample_to_img(SCHAEFER_ATLAS_PATH_116, background_img)
# plotting.plot_roi(atlas_img, bg_img=background_img, title="Schaefer2018_116Parcels")

atlas_dataset = datasets.fetch_atlas_schaefer_2018(n_rois=100, yeo_networks=7, resolution_mm=2)
atlas_map = atlas_dataset.maps
atlas_labels = atlas_dataset.labels

# Visualising fmri + atlas
mean_fmri = image.mean_img(FMRI_FILE_PATH)
plotting.plot_epi(mean_fmri, colorbar=True, cbar_tick_format="%i", title="sub-ADNI002S0295_ses-M060_task-rest_space-MNI152")

plotting.plot_roi(atlas_map, title="Schaefer2018_100Parcels")
plotting.plot_roi(SCHAEFER_ATLAS_PATH_116, title="Schaefer2018_116Parcels")

# %% [markdown]
# Get Schaefer (116 regions) parcellation labels:

# %%
schaefer_116_labels = []

with open(SCHAEFER_100_LABELS, 'r') as s_file:
        schaefer_100_labels = [line.strip() for line in s_file.readlines()]

with open(TIAN_S1_3T_Labels, 'r') as t_file:
        tian_16_labels = [line.strip() for line in t_file.readlines()]

schaefer_116_labels = schaefer_100_labels + tian_16_labels

# %%
print(schaefer_116_labels)
# Out:
# ['Left_VisCent_ExStr_1', 'Left_VisCent_ExStr_2', 'Left_VisCent_ExStr_3', 'Left_VisCent_ExStr_4', 'Left_VisPeri_ExStrInf_1', 'Left_VisPeri_ExStrInf_2', 'Left_VisPeri_ExStrInf_3', 'Left_SomMotA_1', 'Left_SomMotA_2', 'Left_SomMotB_Aud_1', 'Left_SomMotB_Aud_2', 'Left_SomMotB_Aud_3', 'Left_SomMotB_Aud_4', 'Left_DorsAttnA_SPL_1', 'Left_DorsAttnA_SPL_2', 'Left_DorsAttnA_SPL_3', 'Left_DorsAttnB_PostC_1', 'Left_DorsAttnB_PostC_2', 'Left_DorsAttnB_PostC_3', 'Left_DorsAttnB_FEF_1', 'Left_SalVentAttnA_ParOper_1', 'Left_SalVentAttnA_Ins_1', 'Left_SalVentAttnA_Ins_2', 'Left_SalVentAttnA_ParMed_1', 'Left_SalVentAttnA_FrMed_1', 'Left_SalVentAttnB_PFCl_1', 'Left_SalVentAttnB_PFCmp_1', 'Left_Limbic_OFC_1', 'Left_Limbic_TempPole_1', 'Left_Limbic_TempPole_2', 'Left_ContA_IPS_1', 'Left_ContA_PFCl_1', 'Left_ContA_PFCl_2', 'Left_ContB_PFClv_1', 'Left_ContC_pCun_1', 'Left_ContC_pCun_2', 'Left_ContC_Cingp_1', 'Left_DefaultA_PFCd_1', 'Left_DefaultA_PCC_1', 'Left_DefaultA_PFCm_1', 'Left_DefaultB_Temp_1', 'Left_DefaultB_Temp_2', 'Left_DefaultB_IPL_1', 'Left_DefaultB_PFCd_1', 'Left_DefaultB_PFCl_1', 'Left_DefaultB_PFCv_1', 'Left_DefaultB_PFCv_2', 'Left_DefaultC_Rsp_1', 'Left_DefaultC_PHC_1', 'Left_TempPar_1', 'Right_VisCent_ExStr_1', 'Right_VisCent_ExStr_2', 'Right_VisCent_ExStr_3', 'Right_VisPeri_ExStrSup_1', 'Right_VisPeri_ExStrSup_2', 'Right_VisPeri_ExStrSup_3', 'Right_SomMotA_1', 'Right_SomMotA_2', 'Right_SomMotA_3', 'Right_SomMotA_4', 'Right_SomMotB_S2_1', 'Right_SomMotB_S2_2', 'Right_SomMotB_S2_3', 'Right_SomMotB_S2_4', 'Right_DorsAttnA_SPL_1', 'Right_DorsAttnA_SPL_2', 'Right_DorsAttnA_SPL_3', 'Right_DorsAttnB_PostC_1', 'Right_DorsAttnB_PostC_2', 'Right_DorsAttnB_FEF_1', 'Right_SalVentAttnA_ParOper_1', 'Right_SalVentAttnA_Ins_1', 'Right_SalVentAttnA_FrMed_1', 'Right_SalVentAttnA_FrMed_2', 'Right_SalVentAttnB_IPL_1', 'Right_SalVentAttnB_PFCl_1', 'Right_SalVentAttnB_PFCmp_1', 'Right_Limbic_OFC_1', 'Right_Limbic_TempPole_1', 'Right_ContA_IPS_1', 'Right_ContA_PFCl_1', 'Right_ContA_PFCl_2', 'Right_ContB_Temp_1', 'Right_ContB_IPL_1', 'Right_ContB_PFCld_1', 'Right_ContB_PFClv_1', 'Right_ContC_pCun_1', 'Right_ContC_pCun_2', 'Right_DefaultA_IPL_1', 'Right_DefaultA_PFCd_1', 'Right_DefaultA_PCC_1', 'Right_DefaultA_PFCm_1', 'Right_DefaultB_PFCd_1', 'Right_DefaultB_PFCv_1', 'Right_DefaultB_PFCv_2', 'Right_DefaultC_Rsp_1', 'Right_DefaultC_PHC_1', 'Right_TempPar_1', 'Right_TempPar_2', 'Right_TempPar_3', 'HIP-rh', 'AMY-rh', 'pTHA-rh', 'aTHA-rh', 'NAc-rh', 'GP-rh', 'PUT-rh', 'CAU-rh', 'HIP-lh', 'AMY-lh', 'pTHA-lh', 'aTHA-lh', 'NAc-lh', 'GP-lh', 'PUT-lh', 'CAU-lh']

# %% [markdown]
# ## Compute Correlation Matrix

# %%
def compute_fc(masker, fmri_data, trial_name, confounds = None, strategy = None, sample_mask = None, labels = atlas_labels):

    if confounds is not None:
        confound_data = {
            'Shape':  confounds.shape,
            'Columns': confounds.columns.values.tolist()
        }

        confounds=confounds.values
    else:
        confound_data = None
    
    if strategy is not None:
        confounds, sample_mask = load_confounds_strategy(
            img_files=fmri_data,
            **strategy
        )

        confound_data = {
            'Confounds_strategy': strategy,
            'Shape':  confounds.shape,
            'Columns': confounds.columns.values.tolist()
        }
    
    with open(f'fc_trials/{trial_name}.json', 'w') as f:
        f.write(json.dumps(confound_data))

    time_series = masker.fit_transform(fmri_data, confounds=confounds, sample_mask=sample_mask)

    correlation_measure = ConnectivityMeasure(
        kind="correlation",
        standardize="zscore_sample",
    )
    correlation_matrix = correlation_measure.fit_transform([time_series])[0]

    print(correlation_matrix)

    # Make a large figure
    # Mask the main diagonal for visualization:
    np.fill_diagonal(correlation_matrix, 0)
    plot = plotting.plot_matrix(
        correlation_matrix,
        figure=(10, 8),
        labels=labels,
        vmax=0.8,
        vmin=-0.8,
        title=trial_name,
        reorder=True,
    )

    fig = plot.get_figure()
    fig.savefig(f'fc_trials/extract_from_fmri/{trial_name}.png')

    plotting.show()

# %%
# DEFINE MASK

# Extracting signals on a parcellation defined by atlas parcellations
masker = NiftiLabelsMasker(
    # labels_img=atlas_map,
    labels_img=SCHAEFER_ATLAS_PATH_116,
    standardize="zscore_sample",
    standardize_confounds=True,
    high_variance_confounds=True,
    memory="nilearn_cache",
    verbose=5
)

# %% [markdown]
# ### Empirical Confound Removal
#
# Remove a selected set of empirical confounds from the fMRI data

# %%
# PREPROCESSING CONFOUNDS

# Remove NaNs from the Confound File - ignore time step 1 and select a subset of confounds

df = pd.read_csv(CONFOUNDS_FILE_PATH, sep='\t')
confounds = df.iloc[1:, :104]

print("The shape of the confounds matrix is:", confounds.shape)
print(confounds.columns.values)
# Out:
# The shape of the confounds matrix is: (139, 104)
# ['global_signal' 'global_signal_derivative1'
#  'global_signal_derivative1_power2' 'global_signal_power2' 'csf'
#  'csf_derivative1' 'csf_power2' 'csf_derivative1_power2' 'white_matter'
#  'white_matter_derivative1' 'white_matter_derivative1_power2'
#  'white_matter_power2' 'csf_wm' 'tcompcor' 'std_dvars' 'dvars'
#  'framewise_displacement' 'rmsd' 't_comp_cor_00' 't_comp_cor_01'
#  't_comp_cor_02' 't_comp_cor_03' 't_comp_cor_04' 't_comp_cor_05'
#  'c_comp_cor_00' 'c_comp_cor_01' 'c_comp_cor_02' 'c_comp_cor_03'
#  'c_comp_cor_04' 'c_comp_cor_05' 'c_comp_cor_06' 'w_comp_cor_00'
#  'w_comp_cor_01' 'w_comp_cor_02' 'w_comp_cor_03' 'w_comp_cor_04'
#  'w_comp_cor_05' 'w_comp_cor_06' 'w_comp_cor_07' 'w_comp_cor_08'
#  'w_comp_cor_09' 'w_comp_cor_10' 'w_comp_cor_11' 'w_comp_cor_12'
#  'w_comp_cor_13' 'w_comp_cor_14' 'w_comp_cor_15' 'w_comp_cor_16'
#  'w_comp_cor_17' 'w_comp_cor_18' 'w_comp_cor_19' 'w_comp_cor_20'
#  'w_comp_cor_21' 'w_comp_cor_22' 'w_comp_cor_23' 'a_comp_cor_00'
#  'a_comp_cor_01' 'a_comp_cor_02' 'a_comp_cor_03' 'a_comp_cor_04'
#  'a_comp_cor_05' 'a_comp_cor_06' 'a_comp_cor_07' 'a_comp_cor_08'
#  'a_comp_cor_09' 'a_comp_cor_10' 'a_comp_cor_11' 'a_comp_cor_12'
#  'a_comp_cor_13' 'edge_comp_00' 'edge_comp_01' 'edge_comp_02'
#  'edge_comp_03' 'edge_comp_04' 'edge_comp_05' 'edge_comp_06'
#  'edge_comp_07' 'edge_comp_08' 'edge_comp_09' 'edge_comp_10'
#  'edge_comp_11' 'edge_comp_12' 'edge_comp_13' 'edge_comp_14'
#  'edge_comp_15' 'edge_comp_16' 'edge_comp_17' 'edge_comp_18'
#  'edge_comp_19' 'edge_comp_20' 'edge_comp_21' 'edge_comp_22'
#  'edge_comp_23' 'cosine00' 'cosine01' 'cosine02' 'cosine03' 'cosine04'
#  'cosine05' 'cosine06' 'cosine07' 'cosine08' 'cosine09' 'cosine10']

# %%
fmri = image.load_img(FMRI_FILE_PATH)
fmri = image.index_img(fmri, slice(1, None))

# Confound Removal
compute_fc(masker=masker, confounds=confounds, fmri_data=fmri, trial_name='confound_subset_02')
# Out:
# [NiftiLabelsMasker.wrapped] loading data from /Users/dyutichakraborty/nilearn_data/schaefer_2018/Schaefer2018_100Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]1.8s, 0.0min    : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# Resampling labels
# [Memory]3.9s, 0.1min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [[ 1.         -0.11829179  0.1330531  ... -0.21915181  0.08429342
#   -0.02485824]
#  [-0.11829179  1.          0.23763882 ...  0.10149305 -0.0787545
#   -0.18051386]
#  [ 0.1330531   0.23763882  1.         ...  0.12365407 -0.07669691
#   -0.10331584]
#  ...
#  [-0.21915181  0.10149304  0.12365407 ...  1.          0.3000797
#   -0.0313715 ]
#  [ 0.08429342 -0.0787545  -0.07669691 ...  0.3000797   1.
#    0.3381505 ]
#  [-0.02485824 -0.18051386 -0.10331584 ... -0.0313715   0.3381505
#    1.        ]]

# %% [markdown]
# ### No Confound Removal
#
# Plots FC without removing any of the empirical confound data

# %%
# No Confound Removal
compute_fc(masker=masker, fmri_data=FMRI_FILE_PATH_POST_PROCESSED, trial_name='post_processed_fmri_5', labels=schaefer_116_labels)
# Out:
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.high_variance_confounds...
# high_variance_confounds('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S2073_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz')
# __________________________________________high_variance_confounds - 5.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S2073_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x167b3a3d0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.129267, ...,  0.015874],
#        ...,
#        [-0.076932, ..., -0.031736]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S2073_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.3s, 0.2min
# [[1.         0.08552733 0.15433307 ... 0.10916293 0.10572715 0.13239285]
#  [0.08552733 1.         0.1883007  ... 0.05616746 0.03524702 0.19847415]
#  [0.15433307 0.1883007  1.         ... 0.35642534 0.2731609  0.4039065 ]
#  ...
#  [0.10916293 0.05616746 0.35642534 ... 1.         0.49647674 0.5560592 ]
#  [0.10572715 0.03524702 0.2731609  ... 0.49647674 1.         0.56377584]
#  [0.13239284 0.19847415 0.4039065  ... 0.55605924 0.56377584 1.        ]]

# %% [markdown]
# ### Use a Pre-defined Confound Removal Strategy
#
# Use one of Nilearn's pre-defined confound removal strategy, namely compcor:
#
# - 'compcor': Load confounds using the CompCor strategy from Behzadi2007. CompCor estimates noise through principal component analysis on regions that are unlikely to contain signal. Thus it might not be a suitable approach for researchers who want explicit description of the source of noise. Empirically, Compcor has shown similar effect of removing physiological noise as methods that explicitly model and remove physiology signals. Compcor can suffer from loss of temporal degrees of freedom when using explained variance as the noise component estimation as the number of compcor component can be really high. Please refer to fMRIPrep documentation for more details.

# %%
# Strategy
strategy = {
    'denoise_strategy' : 'compcor',
    'compcor':"anat_separated",
    'n_compcor':5
}

compute_fc(masker=masker, fmri_data=FMRI_FILE_PATH, trial_name='compcor_strategy', strategy=strategy)
# Out:
# [NiftiLabelsMasker.wrapped] loading data from /Users/dyutichakraborty/nilearn_data/schaefer_2018/Schaefer2018_100Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]15.9s, 0.3min   : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# [Memory]17.9s, 0.3min   : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [[ 1.          0.29401493  0.3005675  ... -0.1213242   0.28344685
#   -0.07285915]
#  [ 0.29401493  1.          0.57267255 ...  0.19606923  0.30182862
#    0.1174209 ]
#  [ 0.3005675   0.57267255  1.         ...  0.19016421  0.23492612
#    0.07642812]
#  ...
#  [-0.1213242   0.19606923  0.19016421 ...  1.          0.34368014
#    0.24438502]
#  [ 0.28344685  0.30182865  0.23492612 ...  0.34368014  1.
#    0.5285491 ]
#  [-0.07285915  0.1174209   0.07642812 ...  0.24438502  0.5285491
#    1.        ]]

# %% [markdown]
# ## Average Patient FC
# Visualising the average FC matrix across all patients involved in the ADSP-PHC ADNI study

# %%
import nibabel as nib
import os

# Read in fc data for all ADSP-PHC study subjects
ADSP_PHC_SUBJECTS_DIR = '../../data/ADSP-PHC-SUBJECTS/fc/'
adsp_fc_files = os.listdir(ADSP_PHC_SUBJECTS_DIR)

image_files = [os.path.join(ADSP_PHC_SUBJECTS_DIR, file) for file in adsp_fc_files if file.endswith('.nii.gz')]

# %%
c
# Out:
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4262_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]159.4s, 2.7min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4262_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1609423d0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.177781, ...,  0.053596],
#        ...,
#        [ 0.046284, ..., -0.035359]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4262_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.7s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S5230_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]179.1s, 3.0min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S5230_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x16796bf10>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.089778, ..., -0.070952],
#        ...,
#        [-0.160221, ..., -0.000525]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S5230_ses-M060_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 9.8s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6067_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]195.7s, 3.3min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6067_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1678c5850>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[0.119996, ..., 0.039248],
#        ...,
#        [0.039552, ..., 0.061398]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6067_ses-M048_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.2s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4485_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]213.2s, 3.6min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4485_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1679f5850>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.030757, ..., -0.01878 ],
#        ...,
#        [ 0.018597, ..., -0.011261]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4485_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.9s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S0729_ses-M072_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]227.6s, 3.8min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S0729_ses-M072_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x160f44210>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[ 0.016515, ...,  0.047266],
#        ...,
#        [-0.051245, ...,  0.011567]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S0729_ses-M072_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.9s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S4644_ses-M084_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]242.3s, 4.0min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S4644_ses-M084_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x167ad7b90>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.080839, ..., -0.052046],
#        ...,
#        [-0.004604, ...,  0.050318]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S4644_ses-M084_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 10.4s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4357_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]260.2s, 4.3min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4357_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x28b9958d0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.006725, ..., -0.036579],
#        ...,
#        [-0.026862, ...,  0.039764]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4357_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 8.1s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4171_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]274.8s, 4.6min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4171_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1679f5850>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.006914, ...,  0.012468],
#        ...,
#        [ 0.005467, ..., -0.021121]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4171_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.7s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4229_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]288.9s, 4.8min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4229_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x167a0a2d0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[ 0.042021, ...,  0.00666 ],
#        ...,
#        [-0.006214, ...,  0.007355]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4229_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.6s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4225_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]302.6s, 5.0min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4225_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x161011890>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.008828, ...,  0.008817],
#        ...,
#        [ 0.043791, ..., -0.040768]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4225_ses-M024_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.9s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4192_ses-M003_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]316.8s, 5.3min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4192_ses-M003_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x160f162d0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.010582, ...,  0.006669],
#        ...,
#        [ 0.03285 , ..., -0.018434]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI006S4192_ses-M003_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.8s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S1280_ses-M084_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]332.7s, 5.5min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S1280_ses-M084_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x28c33d690>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.054961, ..., -0.087428],
#        ...,
#        [ 0.092346, ..., -0.039579]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S1280_ses-M084_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.0s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4219_ses-M006_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]350.7s, 5.8min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4219_ses-M006_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x160b37ad0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[ 0.020435, ..., -0.023364],
#        ...,
#        [-0.034859, ...,  0.021377]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4219_ses-M006_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 7.6s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4213_ses-M072_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]364.5s, 6.1min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4213_ses-M072_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1679f5850>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.061165, ..., -0.011957],
#        ...,
#        [-0.028856, ..., -0.171877]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4213_ses-M072_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 10.1s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6014_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]381.4s, 6.4min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6014_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x167a0a2d0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[ 0.042423, ...,  0.041479],
#        ...,
#        [-0.022975, ..., -0.002141]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6014_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.4s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S5178_ses-M003_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]399.9s, 6.7min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S5178_ses-M003_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x160f16e90>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[ 0.006965, ..., -0.005331],
#        ...,
#        [-0.031161, ..., -0.04188 ]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S5178_ses-M003_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 9.1s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4213_ses-M006_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]416.0s, 6.9min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4213_ses-M006_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x160af1dd0>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[0.007536, ..., 0.008771],
#        ...,
#        [0.011112, ..., 0.010074]], dtype=float32)], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S4213_ses-M006_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 8.2s, 0.1min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6258_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]432.1s, 7.2min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6258_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x16189a490>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.082081, ..., -0.136791],
#        ...,
#        [ 0.076927, ...,  0.077763]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI003S6258_ses-M000_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.2s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI005S6393_ses-M054_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]452.0s, 7.5min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI005S6393_ses-M054_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1618dac90>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[-0.351369, ..., -0.331418],
#        ...,
#        [-0.033371, ...,  0.025685]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI005S6393_ses-M054_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.8s, 0.2min
# ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S1280_ses-M144_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.wrapped] loading data from ../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# [Memory]591.0s, 9.9min  : Loading high_variance_confounds...
# _____________________________high_variance_confounds cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S1280_ses-M144_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x1678c5850>, { 'background_label': 0,
#   'clean_kwargs': {},
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': True,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': '../../data/atlases/Schaefer2018_116Parcels_7Networks_order_FSLMNI152_2mm.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore_sample',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=[ array([[ 0.007755, ...,  0.006147],
#        ...,
#        [-0.032355, ...,  0.001278]])], sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from ../../data/ADSP-PHC-SUBJECTS/fc/sub-ADNI002S1280_ses-M144_task-rest_space-MNI152Lin_res-2_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _____________________________________________filter_and_extract - 236.8s, 3.9min
# [[1.         0.12089975 0.10008447 ... 0.09918019 0.1398048  0.15284987]
#  [0.12089975 1.         0.11693814 ... 0.05717406 0.07097619 0.17981832]
#  [0.10008447 0.11693814 1.         ... 0.0489646  0.18454506 0.10852022]
#  ...
#  [0.09918019 0.05717406 0.0489646  ... 1.         0.42148756 0.09750996]
#  [0.1398048  0.07097619 0.18454506 ... 0.42148756 1.         0.20919455]
#  [0.15284986 0.17981832 0.10852022 ... 0.09750996 0.20919455 1.        ]]

# %%
# Make a large figure
# Mask the main diagonal for visualization:
np.fill_diagonal(avg_corr, 0)
plot = plotting.plot_matrix(
    avg_corr,
    figure=(15, 12),
    labels=schaefer_116_labels,
    vmax=0.8,
    vmin=-0.8,
    title="Average FC",
    reorder=True,
)

fig = plot.get_figure()
fig.savefig(f'fc_trials/extract_from_fmri/avg_adsp_phc_fc_{SAMPLE_SIZE}.png')

plotting.show()
