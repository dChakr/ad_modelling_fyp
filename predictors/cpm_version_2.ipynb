# %% [markdown]
# # CPM Predictor: Version 2
#
# Inspired by code from https://github.com/YaleMRRC/CPM/tree/master

# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_error
from scipy.stats import spearmanr, t, ttest_1samp, pearsonr
from sklearn.linear_model import LinearRegression
from statsmodels.robust.robust_linear_model import RLM

import json
from joblib import dump

# %%
node_size=100
def compute_correlation(fmri):
    # Calculate the z_score (along the time axis)
    fmri_zscored = (fmri.T - fmri.mean(axis=1)) / fmri.std(axis=1)

    # Calculate the FC 
    fc = np.corrcoef(fmri_zscored.T)
    
    return fc

# %%
threshold = 0.05
def train_cpm(ipmat, pheno):

    """
    Accepts input matrices and pheno data
    Returns model
    
    cpm: in cpm we select the most significant edges for subjects. so each subject
         have a pair set of edges with positive and negative correlation with behavioral subjects.
         It's important to keep both set in final regression task.  
    posedges: positive edges are a set of edges have positive
              correlatin with behavioral measures
    negedges: negative edges are a set of edges have negative
              correlation with behavioral measures
    """
    cc=[spearmanr(pheno,im) for im in ipmat]
    
    rmat=np.array([c[0] for c in cc])
    pmat=np.array([c[1] for c in cc])
    rmat=np.reshape(rmat,[100,100])
    pmat=np.reshape(pmat,[100,100])
    posedges=(rmat > 0) & (pmat < threshold)    # edges correalated with higher ADAS Scores
    posedges=posedges.astype(int)
    negedges=(rmat < 0) & (pmat < threshold)    # edges correalated with lower ADAS Scores
    negedges=negedges.astype(int)
    pe=ipmat[posedges.flatten().astype(bool),:]
    ne=ipmat[negedges.flatten().astype(bool),:]
    pe=pe.sum(axis=0)/2
    ne=ne.sum(axis=0)/2


    if np.sum(pe) != 0:
        fit_pos=np.polyfit(pe,pheno,1)      # fit a curve through the positive edges
    else:
        fit_pos=[]

    if np.sum(ne) != 0:
        fit_neg=np.polyfit(ne,pheno,1)       # fit a curve through the negative edges
    else:
        fit_neg=[]

    return fit_pos,fit_neg,posedges,negedges

def run_validate(X,y,cvtype):
    """
    Accepts input matrices (X), phenotype data (y), and the type of cross-valdiation (cv_type)    
    Returns the R-values for positive model (Rpos), negative model (Rneg), and the combination
    X: the feature matrix of size (number of nodes x number of nodes x number of subjects)
    y: the phenotype vector of size (number of subjects)
    cv_type: the cross-valdiation type, takes one of the followings: 
    1) LOO: leave-one-out cross-validation
    2) 5k: 
    """
    numsubs=X.shape[2]
    X=np.reshape(X,[-1,numsubs])
    
    if cvtype == 'LOO':
        behav_pred_pos=np.zeros([numsubs])
        behav_pred_neg=np.zeros([numsubs])
        for loo in range(0,numsubs):

            print("Running LOO, sub no:",loo)
      
            train_mats=np.delete(X,[loo],axis=1)
            train_pheno=np.delete(y,[loo],axis=0)
            
            test_mat=X[:,loo]
            test_pheno=y[loo]

            pos_fit,neg_fit,posedges,negedges=train_cpm(train_mats,train_pheno)

            pe=np.sum(test_mat[posedges.flatten().astype(bool)])/2
            ne=np.sum(test_mat[negedges.flatten().astype(bool)])/2
            
            # Run model on test subject

            if len(pos_fit) > 0:
                behav_pred_pos[loo]=pos_fit[0]*pe + pos_fit[1]       # predict using the coefficients of the curve
            else:
                behav_pred_pos[loo]='nan'

            if len(neg_fit) > 0:
                behav_pred_neg[loo]=neg_fit[0]*ne + neg_fit[1]
            else:
                behav_pred_neg[loo]='nan'
          
        return behav_pred_pos, behav_pred_neg

# %% [markdown]
# ### Get Features (FC Matrices)

# %%
results = []

# %%
def normalise_correlate_fc(fmri):
    fc_emp = fmri / np.max(fmri)
    fc_emp = np.corrcoef(fc_emp)
    return fc_emp

# %%
# ADAS_DATA = '../data/ADAS_ADNIGO23_17Apr2024_FILTERED_wfiles_197.csv'
# PHC_DATA = '../data/ADSP_PHC_COGN_Dec2023_FILTERED_wfiles.csv'
ADNI_MERGE = '../data/ADNIMERGE/ADNIMERGE_29Apr2024_wFiles.csv'
df = pd.read_csv(ADNI_MERGE)

# df = df.drop(columns=['RID', 'VISCODE2', 'PHC_Diagnosis', 'PHC_EXF', 'PHC_LAN', 'PHC_VSP'])
df.head()
# Out:
#    Unnamed: 0   RID COLPROT ORIGPROT        PTID  SITE VISCODE    EXAMDATE  \
# 0          49  5280   ADNI2    ADNI2  100_S_5280   100    M024  2015-09-29
# 1         659  5265   ADNI2    ADNI2  007_S_5265     7    M024  2015-08-25
# 2         702  5262   ADNI2    ADNI2  018_S_5262    18    M000  2013-09-03
# 3        1203  5250   ADNI2    ADNI2  018_S_5250    18    M000  2013-09-05
# 4        1446  5242   ADNI2    ADNI2  019_S_5242    19    M000  2013-07-11
#
#   DX_bl   AGE  ...   FDG_bl  PIB_bl AV45_bl FBB_bl Years_bl  Month_bl  Month  \
# 0   SMC  67.5  ...  1.19409     NaN  0.9851    NaN  2.03149   24.3279     24
# 1   SMC  75.1  ...  1.28381     NaN  1.2359    NaN  2.03422   24.3607     24
# 2   SMC  73.5  ...      NaN     NaN     NaN    NaN  0.00000    0.0000      0
# 3   SMC  73.9  ...  1.21422     NaN  1.0664    NaN  0.00000    0.0000      0
# 4   SMC  67.2  ...  1.29605     NaN  0.9090    NaN  0.00000    0.0000      0
#
#     M           update_stamp  \
# 0  24  2023-07-07 05:00:02.0
# 1  24  2023-07-07 05:00:01.0
# 2   0  2023-07-07 05:00:01.0
# 3   0  2023-07-07 05:00:01.0
# 4   0  2023-07-07 05:00:01.0
#
#                                              FC_DATA
# 0  ../FMRI_ADNI_DATA/fc/sub-ADNI100S5280_ses-M024...
# 1  ../FMRI_ADNI_DATA/fc/sub-ADNI007S5265_ses-M024...
# 2  ../FMRI_ADNI_DATA/fc/sub-ADNI018S5262_ses-M000...
# 3  ../FMRI_ADNI_DATA/fc/sub-ADNI018S5250_ses-M000...
# 4  ../FMRI_ADNI_DATA/fc/sub-ADNI019S5242_ses-M000...
#
# [5 rows x 118 columns]

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'RID',
#  'COLPROT',
#  'ORIGPROT',
#  'PTID',
#  'SITE',
#  'VISCODE',
#  'EXAMDATE',
#  'DX_bl',
#  'AGE',
#  'PTGENDER',
#  'PTEDUCAT',
#  'PTETHCAT',
#  'PTRACCAT',
#  'PTMARRY',
#  'APOE4',
#  'FDG',
#  'PIB',
#  'AV45',
#  'FBB',
#  'ABETA',
#  'TAU',
#  'PTAU',
#  'CDRSB',
#  'ADAS11',
#  'ADAS13',
#  'ADASQ4',
#  'MMSE',
#  'RAVLT_immediate',
#  'RAVLT_learning',
#  'RAVLT_forgetting',
#  'RAVLT_perc_forgetting',
#  'LDELTOTAL',
#  'DIGITSCOR',
#  'TRABSCOR',
#  'FAQ',
#  'MOCA',
#  'EcogPtMem',
#  'EcogPtLang',
#  'EcogPtVisspat',
#  'EcogPtPlan',
#  'EcogPtOrgan',
#  'EcogPtDivatt',
#  'EcogPtTotal',
#  'EcogSPMem',
#  'EcogSPLang',
#  'EcogSPVisspat',
#  'EcogSPPlan',
#  'EcogSPOrgan',
#  'EcogSPDivatt',
#  'EcogSPTotal',
#  'FLDSTRENG',
#  'FSVERSION',
#  'IMAGEUID',
#  'Ventricles',
#  'Hippocampus',
#  'WholeBrain',
#  'Entorhinal',
#  'Fusiform',
#  'MidTemp',
#  'ICV',
#  'DX',
#  'mPACCdigit',
#  'mPACCtrailsB',
#  'EXAMDATE_bl',
#  'CDRSB_bl',
#  'ADAS11_bl',
#  'ADAS13_bl',
#  'ADASQ4_bl',
#  'MMSE_bl',
#  'RAVLT_immediate_bl',
#  'RAVLT_learning_bl',
#  'RAVLT_forgetting_bl',
#  'RAVLT_perc_forgetting_bl',
#  'LDELTOTAL_BL',
#  'DIGITSCOR_bl',
#  'TRABSCOR_bl',
#  'FAQ_bl',
#  'mPACCdigit_bl',
#  'mPACCtrailsB_bl',
#  'FLDSTRENG_bl',
#  'FSVERSION_bl',
#  'IMAGEUID_bl',
#  'Ventricles_bl',
#  'Hippocampus_bl',
#  'WholeBrain_bl',
#  'Entorhinal_bl',
#  'Fusiform_bl',
#  'MidTemp_bl',
#  'ICV_bl',
#  'MOCA_bl',
#  'EcogPtMem_bl',
#  'EcogPtLang_bl',
#  'EcogPtVisspat_bl',
#  'EcogPtPlan_bl',
#  'EcogPtOrgan_bl',
#  'EcogPtDivatt_bl',
#  'EcogPtTotal_bl',
#  'EcogSPMem_bl',
#  'EcogSPLang_bl',
#  'EcogSPVisspat_bl',
#  'EcogSPPlan_bl',
#  'EcogSPOrgan_bl',
#  'EcogSPDivatt_bl',
#  'EcogSPTotal_bl',
#  'ABETA_bl',
#  'TAU_bl',
#  'PTAU_bl',
#  'FDG_bl',
#  'PIB_bl',
#  'AV45_bl',
#  'FBB_bl',
#  'Years_bl',
#  'Month_bl',
#  'Month',
#  'M',
#  'update_stamp',
#  'FC_DATA']

# %%
adni_df = df[['RID', 'VISCODE', 'ADAS11', 'PTEDUCAT', 'ADAS13', 'DX', 'DX_bl', 'FC_DATA']]
adni_df = adni_df.dropna(subset=['ADAS11'])

adni_df.shape
# Out:
# (1339, 8)

# %%
plt.figure(figsize=(8, 6))
plt.hist(adni_df['ADAS11'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of ADAS11 Scores in Participants')
plt.xlabel('ADAS11 Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.axis('on')
# plt.savefig('../data/adas11_score_dist_20bins.png')

plt.show()

# %% [markdown]
# ### Compare Proportional and Stratified Sampling
#
# We want to see the differences in the distributions of using proportional and stratified sampling methods

# %%
grouped = adni_df.groupby('DX_bl')

# Accessing each group
for category, group in grouped:
    print("Category:", category)
    print(group.shape)
# Out:
# Category: AD
# (100, 8)
# Category: CN
# (362, 8)
# Category: EMCI
# (302, 8)
# Category: LMCI
# (247, 8)
# Category: SMC
# (328, 8)

# %%
# PROPORTIONAL SAMPLING FROM EACH PATIENT GROUP
# Get 5% of each patient group

sample_df = None
total_sample = 0

for category, group in grouped:
    f = group.shape[0]
    sample_n = 1 if f * 0.05 < 1 else round(f * 0.05)
#     print(sample_n)

    random = group.sample(sample_n)
    sample_df = pd.concat([sample_df, random])

sample_df = sample_df.reset_index(drop=True)
print(sample_df.shape)

# STRATIFIED SAMPLING FROM EACH PATIENT GROUP
# Want a sample of size 100 from each bucket

sample_eq_df = None
sample_n = 100

for category, group in grouped:
    f = group.shape[0]
    bucket_n = sample_n if f > sample_n else f

    random = group.sample(bucket_n)
    sample_eq_df = pd.concat([sample_eq_df, random])

sample_eq_df = sample_eq_df.reset_index(drop=True)
print(sample_eq_df.shape)
# Out:
# (66, 8)
# (500, 8)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

ax[0].hist(sample_df['ADAS11'], bins=20, color='skyblue', edgecolor='black')
ax[0].set_title('Distribution of ADAS11 Scores in Participants (Proportional Sample, n = 66)')
ax[0].set_xlabel('ADAS11 Score')
ax[0].set_ylabel('Frequency')
ax[0].grid(True)
ax[0].axis('on')

ax[1].hist(sample_eq_df['ADAS11'], bins=20, color='skyblue', edgecolor='black')
ax[1].set_title('Distribution of ADAS11 Scores in Participants (Stratified Sample, n = 500)')
ax[1].set_xlabel('ADAS11 Score')
ax[1].set_ylabel('Frequency')
ax[1].grid(True)
ax[1].axis('on')

# plt.savefig('../data/adas11_score_sample_comp.png')

# plt.scatter(adni_df['PTEDUCAT'], adni_df['ADAS11'])
# sns.regplot(x='PTEDUCAT', y='ADAS11', data=adni_df, line_kws={'color':'red'})
# plt.xlabel('Education (Years)')  # Replace 'X Axis Label' with the label for your x-axis
# plt.ylabel('ADAS11 Cognitive Score')  # Replace 'Y Axis Label' with the label for your y-axis
# plt.title('Education (Years) against ADAS11 Cognitive Score')   # Replace 'Scatter Plot' with the title for your plot
# plt.savefig('../data/adas11_score_against_education.png')

plt.show()

# %%
# Get feature-set for one of the stratified sampling method

dim_x = len(df)
X = []

for i, file in enumerate(sample_eq_df['FC_DATA'].values):
    arr = loadmat(f'../{file}')['ROI_activity'][:100, :] # get the first 100 regions
    fc = compute_correlation(arr)
    
    # Add noise along the diagonal
    noise_level = 0.0001  # Adjust this value as needed
    noise = np.random.randn(100) * noise_level
    fc_with_noise = fc + np.diag(noise)
    
    X.append(fc_with_noise)
X = np.array(X)

Y = sample_eq_df['ADAS11']
print(Y.shape)

X_strat_transposed = np.transpose(X, (1, 2, 0))
print(X_strat_transposed.shape)
# Out:
# (500,)
# (100, 100, 500)

# %%
behav_pred_pos, behav_pred_neg = run_validate(X_strat_transposed, Y, 'LOO')
# Out:
# Running LOO, sub no: 0
# Running LOO, sub no: 1
# Running LOO, sub no: 2
# Running LOO, sub no: 3
# Running LOO, sub no: 4
# Running LOO, sub no: 5
# Running LOO, sub no: 6
# Running LOO, sub no: 7
# Running LOO, sub no: 8
# Running LOO, sub no: 9
# Running LOO, sub no: 10
# Running LOO, sub no: 11
# Running LOO, sub no: 12
# Running LOO, sub no: 13
# Running LOO, sub no: 14
# Running LOO, sub no: 15
# Running LOO, sub no: 16
# Running LOO, sub no: 17
# Running LOO, sub no: 18
# Running LOO, sub no: 19
# Running LOO, sub no: 20
# Running LOO, sub no: 21
# Running LOO, sub no: 22
# Running LOO, sub no: 23
# Running LOO, sub no: 24
# Running LOO, sub no: 25
# Running LOO, sub no: 26
# Running LOO, sub no: 27
# Running LOO, sub no: 28
# Running LOO, sub no: 29
# Running LOO, sub no: 30
# Running LOO, sub no: 31
# Running LOO, sub no: 32
# Running LOO, sub no: 33
# Running LOO, sub no: 34
# Running LOO, sub no: 35
# Running LOO, sub no: 36
# Running LOO, sub no: 37
# Running LOO, sub no: 38
# Running LOO, sub no: 39
# Running LOO, sub no: 40
# Running LOO, sub no: 41
# Running LOO, sub no: 42
# Running LOO, sub no: 43
# Running LOO, sub no: 44
# Running LOO, sub no: 45
# Running LOO, sub no: 46
# Running LOO, sub no: 47
# Running LOO, sub no: 48
# Running LOO, sub no: 49
# Running LOO, sub no: 50
# Running LOO, sub no: 51
# Running LOO, sub no: 52
# Running LOO, sub no: 53
# Running LOO, sub no: 54
# Running LOO, sub no: 55
# Running LOO, sub no: 56
# Running LOO, sub no: 57
# Running LOO, sub no: 58
# Running LOO, sub no: 59
# Running LOO, sub no: 60
# Running LOO, sub no: 61
# Running LOO, sub no: 62
# Running LOO, sub no: 63
# Running LOO, sub no: 64
# Running LOO, sub no: 65
# Running LOO, sub no: 66
# Running LOO, sub no: 67
# Running LOO, sub no: 68
# Running LOO, sub no: 69
# Running LOO, sub no: 70
# Running LOO, sub no: 71
# Running LOO, sub no: 72
# Running LOO, sub no: 73
# Running LOO, sub no: 74
# Running LOO, sub no: 75
# Running LOO, sub no: 76
# Running LOO, sub no: 77
# Running LOO, sub no: 78
# Running LOO, sub no: 79
# Running LOO, sub no: 80
# Running LOO, sub no: 81
# Running LOO, sub no: 82
# Running LOO, sub no: 83
# Running LOO, sub no: 84
# Running LOO, sub no: 85
# Running LOO, sub no: 86
# Running LOO, sub no: 87
# Running LOO, sub no: 88
# Running LOO, sub no: 89
# Running LOO, sub no: 90
# Running LOO, sub no: 91
# Running LOO, sub no: 92
# Running LOO, sub no: 93
# Running LOO, sub no: 94
# Running LOO, sub no: 95
# Running LOO, sub no: 96
# Running LOO, sub no: 97
# Running LOO, sub no: 98
# Running LOO, sub no: 99
# Running LOO, sub no: 100
# Running LOO, sub no: 101
# Running LOO, sub no: 102
# Running LOO, sub no: 103
# Running LOO, sub no: 104
# Running LOO, sub no: 105
# Running LOO, sub no: 106
# Running LOO, sub no: 107
# Running LOO, sub no: 108
# Running LOO, sub no: 109
# Running LOO, sub no: 110
# Running LOO, sub no: 111
# Running LOO, sub no: 112
# Running LOO, sub no: 113
# Running LOO, sub no: 114
# Running LOO, sub no: 115
# Running LOO, sub no: 116
# Running LOO, sub no: 117
# Running LOO, sub no: 118
# Running LOO, sub no: 119
# Running LOO, sub no: 120
# Running LOO, sub no: 121
# Running LOO, sub no: 122
# Running LOO, sub no: 123
# Running LOO, sub no: 124
# Running LOO, sub no: 125
# Running LOO, sub no: 126
# Running LOO, sub no: 127
# Running LOO, sub no: 128
# Running LOO, sub no: 129
# Running LOO, sub no: 130
# Running LOO, sub no: 131
# Running LOO, sub no: 132
# Running LOO, sub no: 133
# Running LOO, sub no: 134
# Running LOO, sub no: 135
# Running LOO, sub no: 136
# Running LOO, sub no: 137
# Running LOO, sub no: 138
# Running LOO, sub no: 139
# Running LOO, sub no: 140
# Running LOO, sub no: 141
# Running LOO, sub no: 142
# Running LOO, sub no: 143
# Running LOO, sub no: 144
# Running LOO, sub no: 145
# Running LOO, sub no: 146
# Running LOO, sub no: 147
# Running LOO, sub no: 148
# Running LOO, sub no: 149
# Running LOO, sub no: 150
# Running LOO, sub no: 151
# Running LOO, sub no: 152
# Running LOO, sub no: 153
# Running LOO, sub no: 154
# Running LOO, sub no: 155
# Running LOO, sub no: 156
# Running LOO, sub no: 157
# Running LOO, sub no: 158
# Running LOO, sub no: 159
# Running LOO, sub no: 160
# Running LOO, sub no: 161
# Running LOO, sub no: 162
# Running LOO, sub no: 163
# Running LOO, sub no: 164
# Running LOO, sub no: 165
# Running LOO, sub no: 166
# Running LOO, sub no: 167
# Running LOO, sub no: 168
# Running LOO, sub no: 169
# Running LOO, sub no: 170
# Running LOO, sub no: 171
# Running LOO, sub no: 172
# Running LOO, sub no: 173
# Running LOO, sub no: 174
# Running LOO, sub no: 175
# Running LOO, sub no: 176
# Running LOO, sub no: 177
# Running LOO, sub no: 178
# Running LOO, sub no: 179
# Running LOO, sub no: 180
# Running LOO, sub no: 181
# Running LOO, sub no: 182
# Running LOO, sub no: 183
# Running LOO, sub no: 184
# Running LOO, sub no: 185
# Running LOO, sub no: 186
# Running LOO, sub no: 187
# Running LOO, sub no: 188
# Running LOO, sub no: 189
# Running LOO, sub no: 190
# Running LOO, sub no: 191
# Running LOO, sub no: 192
# Running LOO, sub no: 193
# Running LOO, sub no: 194
# Running LOO, sub no: 195
# Running LOO, sub no: 196
# Running LOO, sub no: 197
# Running LOO, sub no: 198
# Running LOO, sub no: 199
# Running LOO, sub no: 200
# Running LOO, sub no: 201
# Running LOO, sub no: 202
# Running LOO, sub no: 203
# Running LOO, sub no: 204
# Running LOO, sub no: 205
# Running LOO, sub no: 206
# Running LOO, sub no: 207
# Running LOO, sub no: 208
# Running LOO, sub no: 209
# Running LOO, sub no: 210
# Running LOO, sub no: 211
# Running LOO, sub no: 212
# Running LOO, sub no: 213
# Running LOO, sub no: 214
# Running LOO, sub no: 215
# Running LOO, sub no: 216
# Running LOO, sub no: 217
# Running LOO, sub no: 218
# Running LOO, sub no: 219
# Running LOO, sub no: 220
# Running LOO, sub no: 221
# Running LOO, sub no: 222
# Running LOO, sub no: 223
# Running LOO, sub no: 224
# Running LOO, sub no: 225
# Running LOO, sub no: 226
# Running LOO, sub no: 227
# Running LOO, sub no: 228
# Running LOO, sub no: 229
# Running LOO, sub no: 230
# Running LOO, sub no: 231
# Running LOO, sub no: 232
# Running LOO, sub no: 233
# Running LOO, sub no: 234
# Running LOO, sub no: 235
# Running LOO, sub no: 236
# Running LOO, sub no: 237
# Running LOO, sub no: 238
# Running LOO, sub no: 239
# Running LOO, sub no: 240
# Running LOO, sub no: 241
# Running LOO, sub no: 242
# Running LOO, sub no: 243
# Running LOO, sub no: 244
# Running LOO, sub no: 245
# Running LOO, sub no: 246
# Running LOO, sub no: 247
# Running LOO, sub no: 248
# Running LOO, sub no: 249
# Running LOO, sub no: 250
# Running LOO, sub no: 251
# Running LOO, sub no: 252
# Running LOO, sub no: 253
# Running LOO, sub no: 254
# Running LOO, sub no: 255
# Running LOO, sub no: 256
# Running LOO, sub no: 257
# Running LOO, sub no: 258
# Running LOO, sub no: 259
# Running LOO, sub no: 260
# Running LOO, sub no: 261
# Running LOO, sub no: 262
# Running LOO, sub no: 263
# Running LOO, sub no: 264
# Running LOO, sub no: 265
# Running LOO, sub no: 266
# Running LOO, sub no: 267
# Running LOO, sub no: 268
# Running LOO, sub no: 269
# Running LOO, sub no: 270
# Running LOO, sub no: 271
# Running LOO, sub no: 272
# Running LOO, sub no: 273
# Running LOO, sub no: 274
# Running LOO, sub no: 275
# Running LOO, sub no: 276
# Running LOO, sub no: 277
# Running LOO, sub no: 278
# Running LOO, sub no: 279
# Running LOO, sub no: 280
# Running LOO, sub no: 281
# Running LOO, sub no: 282
# Running LOO, sub no: 283
# Running LOO, sub no: 284
# Running LOO, sub no: 285
# Running LOO, sub no: 286
# Running LOO, sub no: 287
# Running LOO, sub no: 288
# Running LOO, sub no: 289
# Running LOO, sub no: 290
# Running LOO, sub no: 291
# Running LOO, sub no: 292
# Running LOO, sub no: 293
# Running LOO, sub no: 294
# Running LOO, sub no: 295
# Running LOO, sub no: 296
# Running LOO, sub no: 297
# Running LOO, sub no: 298
# Running LOO, sub no: 299
# Running LOO, sub no: 300
# Running LOO, sub no: 301
# Running LOO, sub no: 302
# Running LOO, sub no: 303
# Running LOO, sub no: 304
# Running LOO, sub no: 305
# Running LOO, sub no: 306
# Running LOO, sub no: 307
# Running LOO, sub no: 308
# Running LOO, sub no: 309
# Running LOO, sub no: 310
# Running LOO, sub no: 311
# Running LOO, sub no: 312
# Running LOO, sub no: 313
# Running LOO, sub no: 314
# Running LOO, sub no: 315
# Running LOO, sub no: 316
# Running LOO, sub no: 317
# Running LOO, sub no: 318
# Running LOO, sub no: 319
# Running LOO, sub no: 320
# Running LOO, sub no: 321
# Running LOO, sub no: 322
# Running LOO, sub no: 323
# Running LOO, sub no: 324
# Running LOO, sub no: 325
# Running LOO, sub no: 326
# Running LOO, sub no: 327
# Running LOO, sub no: 328
# Running LOO, sub no: 329
# Running LOO, sub no: 330
# Running LOO, sub no: 331
# Running LOO, sub no: 332
# Running LOO, sub no: 333
# Running LOO, sub no: 334
# Running LOO, sub no: 335
# Running LOO, sub no: 336
# Running LOO, sub no: 337
# Running LOO, sub no: 338
# Running LOO, sub no: 339
# Running LOO, sub no: 340
# Running LOO, sub no: 341
# Running LOO, sub no: 342
# Running LOO, sub no: 343
# Running LOO, sub no: 344
# Running LOO, sub no: 345
# Running LOO, sub no: 346
# Running LOO, sub no: 347
# Running LOO, sub no: 348
# Running LOO, sub no: 349
# Running LOO, sub no: 350
# Running LOO, sub no: 351
# Running LOO, sub no: 352
# Running LOO, sub no: 353
# Running LOO, sub no: 354
# Running LOO, sub no: 355
# Running LOO, sub no: 356
# Running LOO, sub no: 357
# Running LOO, sub no: 358
# Running LOO, sub no: 359
# Running LOO, sub no: 360
# Running LOO, sub no: 361
# Running LOO, sub no: 362
# Running LOO, sub no: 363
# Running LOO, sub no: 364
# Running LOO, sub no: 365
# Running LOO, sub no: 366
# Running LOO, sub no: 367
# Running LOO, sub no: 368
# Running LOO, sub no: 369
# Running LOO, sub no: 370
# Running LOO, sub no: 371
# Running LOO, sub no: 372
# Running LOO, sub no: 373
# Running LOO, sub no: 374
# Running LOO, sub no: 375
# Running LOO, sub no: 376
# Running LOO, sub no: 377
# Running LOO, sub no: 378
# Running LOO, sub no: 379
# Running LOO, sub no: 380
# Running LOO, sub no: 381
# Running LOO, sub no: 382
# Running LOO, sub no: 383
# Running LOO, sub no: 384
# Running LOO, sub no: 385
# Running LOO, sub no: 386
# Running LOO, sub no: 387
# Running LOO, sub no: 388
# Running LOO, sub no: 389
# Running LOO, sub no: 390
# Running LOO, sub no: 391
# Running LOO, sub no: 392
# Running LOO, sub no: 393
# Running LOO, sub no: 394
# Running LOO, sub no: 395
# Running LOO, sub no: 396
# Running LOO, sub no: 397
# Running LOO, sub no: 398
# Running LOO, sub no: 399
# Running LOO, sub no: 400
# Running LOO, sub no: 401
# Running LOO, sub no: 402
# Running LOO, sub no: 403
# Running LOO, sub no: 404
# Running LOO, sub no: 405
# Running LOO, sub no: 406
# Running LOO, sub no: 407
# Running LOO, sub no: 408
# Running LOO, sub no: 409
# Running LOO, sub no: 410
# Running LOO, sub no: 411
# Running LOO, sub no: 412
# Running LOO, sub no: 413
# Running LOO, sub no: 414
# Running LOO, sub no: 415
# Running LOO, sub no: 416
# Running LOO, sub no: 417
# Running LOO, sub no: 418
# Running LOO, sub no: 419
# Running LOO, sub no: 420
# Running LOO, sub no: 421
# Running LOO, sub no: 422
# Running LOO, sub no: 423
# Running LOO, sub no: 424
# Running LOO, sub no: 425
# Running LOO, sub no: 426
# Running LOO, sub no: 427
# Running LOO, sub no: 428
# Running LOO, sub no: 429
# Running LOO, sub no: 430
# Running LOO, sub no: 431
# Running LOO, sub no: 432
# Running LOO, sub no: 433
# Running LOO, sub no: 434
# Running LOO, sub no: 435
# Running LOO, sub no: 436
# Running LOO, sub no: 437
# Running LOO, sub no: 438
# Running LOO, sub no: 439
# Running LOO, sub no: 440
# Running LOO, sub no: 441
# Running LOO, sub no: 442
# Running LOO, sub no: 443
# Running LOO, sub no: 444
# Running LOO, sub no: 445
# Running LOO, sub no: 446
# Running LOO, sub no: 447
# Running LOO, sub no: 448
# Running LOO, sub no: 449
# Running LOO, sub no: 450
# Running LOO, sub no: 451
# Running LOO, sub no: 452
# Running LOO, sub no: 453
# Running LOO, sub no: 454
# Running LOO, sub no: 455
# Running LOO, sub no: 456
# Running LOO, sub no: 457
# Running LOO, sub no: 458
# Running LOO, sub no: 459
# Running LOO, sub no: 460
# Running LOO, sub no: 461
# Running LOO, sub no: 462
# Running LOO, sub no: 463
# Running LOO, sub no: 464
# Running LOO, sub no: 465
# Running LOO, sub no: 466
# Running LOO, sub no: 467
# Running LOO, sub no: 468
# Running LOO, sub no: 469
# Running LOO, sub no: 470
# Running LOO, sub no: 471
# Running LOO, sub no: 472
# Running LOO, sub no: 473
# Running LOO, sub no: 474
# Running LOO, sub no: 475
# Running LOO, sub no: 476
# Running LOO, sub no: 477
# Running LOO, sub no: 478
# Running LOO, sub no: 479
# Running LOO, sub no: 480
# Running LOO, sub no: 481
# Running LOO, sub no: 482
# Running LOO, sub no: 483
# Running LOO, sub no: 484
# Running LOO, sub no: 485
# Running LOO, sub no: 486
# Running LOO, sub no: 487
# Running LOO, sub no: 488
# Running LOO, sub no: 489
# Running LOO, sub no: 490
# Running LOO, sub no: 491
# Running LOO, sub no: 492
# Running LOO, sub no: 493
# Running LOO, sub no: 494
# Running LOO, sub no: 495
# Running LOO, sub no: 496
# Running LOO, sub no: 497
# Running LOO, sub no: 498
# Running LOO, sub no: 499

# %%
behav_pred_pos
res = {
    'noise': 0.0001, 
    'p_threshold': 0.01,
    'fc_gen_method': 'compute_correlation', 
    'sample_method': 'stratified',
    'pearson_r_pos': pearsonr(behav_pred_pos,Y)[0], 
    'pearson_r_neg': pearsonr(behav_pred_neg,Y)[0],
    'spearman_rho_pos': spearmanr(behav_pred_pos,Y, nan_policy='omit')[0], 
    'spearman_rho_neg': spearmanr(behav_pred_neg,Y, nan_policy='omit')[0], 
    'r2_pos': r2_score(Y, behav_pred_pos), 
    'r2_neg': r2_score(Y, behav_pred_neg), 
    'mse_pos': mean_squared_error(behav_pred_pos,Y),
    'mse_neg': mean_squared_error(behav_pred_neg,Y)
}

# %%
res
# Out:
# {'noise': 0.0001,
#  'p_threshold': 0.01,
#  'fc_gen_method': 'compute_correlation',
#  'sample_method': 'stratified',
#  'pearson_r_pos': 0.0776388468829477,
#  'pearson_r_neg': 0.07123628153912245,
#  'spearman_rho_pos': 0.09321467879121464,
#  'spearman_rho_neg': 0.09179777380503013,
#  'r2_pos': 0.002609046742818366,
#  'r2_neg': 0.0020279764629165253,
#  'mse_pos': 64.73255567680067,
#  'mse_neg': 64.77026823487336}

# %%
results
# Out:
# [{'no_files': 66,
#   'noise': 0.0001,
#   'p_threshold': 0.05,
#   'fc_gen_method': 'compute_correlation',
#   'sample_method': 'stratified',
#   'pearson_r_pos': 0.19429768976696976,
#   'pearson_r_neg': -0.07140965598750981,
#   'spearman_rho_pos': 0.12645353033336565,
#   'spearman_rho_neg': -0.09444315219874633,
#   'r2_pos': -5.617831230610038,
#   'r2_neg': -10.537068237202183,
#   'mse_pos': 47.85370729259691,
#   'mse_neg': 54.80550807383122}]

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#    no_files   noise  p_threshold        fc_gen_method sample_method  \
# 0        66  0.0001         0.05  compute_correlation    stratified
#
#    pearson_r_pos  pearson_r_neg  spearman_rho_pos  spearman_rho_neg    r2_pos  \
# 0       0.194298       -0.07141          0.126454         -0.094443 -5.617831
#
#       r2_neg    mse_pos    mse_neg
# 0 -10.537068  47.853707  54.805508

# %%
# Save results
results_df.to_csv('cpm_adas11_exp.csv')

# %% [markdown]
# ## Get Sample of Patients
#
# Compare the different sampling techniques for ADAS PHC Composites and experiment with sample sizes for the ADAS-Cog score

# %%
# Define the number of buckets
n_buckets = 10

# Define the bins for splitting the column into buckets (for ADAS PHC Distribution)
bins = pd.cut(df['PHC_MEM'], bins=n_buckets, labels=False)

# %%
bins
# Out:
# 0       7.0
# 1       7.0
# 2       6.0
# 3       7.0
# 4       7.0
#        ...
# 1337    4.0
# 1338    9.0
# 1339    7.0
# 1340    5.0
# 1341    6.0
# Name: PHC_MEM, Length: 1342, dtype: float64

# %%
# Group the DataFrame by the bins and create a dictionary of DataFrames
buckets = {i: group for i, group in df.groupby(bins)}

# %%
for i in range(n_buckets):
    bucket = buckets.get(i)
    if bucket is not None:
        print(f"Bucket {i}:")
        print(bucket.shape)
# Out:
# Bucket 0:
# (2, 3)
# Bucket 1:
# (10, 3)
# Bucket 2:
# (22, 3)
# Bucket 3:
# (84, 3)
# Bucket 4:
# (117, 3)
# Bucket 5:
# (262, 3)
# Bucket 6:
# (342, 3)
# Bucket 7:
# (324, 3)
# Bucket 8:
# (150, 3)
# Bucket 9:
# (28, 3)

# %% [markdown]
# ### Proportional Sampling

# %%
sample_df = None
total_sample = 0

for i in range(n_buckets):
    bucket = buckets.get(i)
    if bucket is not None:
        f = bucket.shape[0]
        sample_n = 1 if f * 0.1 < 1 else round(f * 0.1)
        print(sample_n)
        
        random = bucket.sample(sample_n)
        sample_df = pd.concat([sample_df, random])

sample_df = sample_df.reset_index(drop=True)
sample_df.shape
# Out:
# 1
# 1
# 2
# 8
# 12
# 26
# 34
# 32
# 15
# 3
# (134, 3)

# %%
sample_df
# Out:
#      Unnamed: 0  PHC_MEM                                            FC_DATA
# 0           229   -2.430  ../FMRI_ADNI_DATA/fc/sub-ADNI127S0259_ses-M150...
# 1          2429   -2.029  ../FMRI_ADNI_DATA/fc/sub-ADNI018S4696_ses-M006...
# 2          2644   -1.584  ../FMRI_ADNI_DATA/fc/sub-ADNI126S4891_ses-M120...
# 3          1796   -1.418  ../FMRI_ADNI_DATA/fc/sub-ADNI009S4324_ses-M090...
# 4          3844   -1.094  ../FMRI_ADNI_DATA/fc/sub-ADNI027S6733_ses-M000...
# ..          ...      ...                                                ...
# 129        2338    1.684  ../FMRI_ADNI_DATA/fc/sub-ADNI007S4620_ses-M024...
# 130        1586    1.465  ../FMRI_ADNI_DATA/fc/sub-ADNI002S4213_ses-M072...
# 131        1881    2.104  ../FMRI_ADNI_DATA/fc/sub-ADNI029S4384_ses-M072...
# 132        2292    2.019  ../FMRI_ADNI_DATA/fc/sub-ADNI031S4590_ses-M006...
# 133        2577    2.142  ../FMRI_ADNI_DATA/fc/sub-ADNI070S4856_ses-M066...
#
# [134 rows x 3 columns]

# %%
dim_x = len(sample_df)
X_prop = []

for i, file in enumerate(sample_df['FC_DATA'].values):
    arr = loadmat(f'../{file}')['ROI_activity'][:100, :] # get the first 100 regions
    fc = compute_correlation(arr)
    
    # Add noise along the diagonal
    noise_level = 0.0001  # Adjust this value as needed
    noise = np.random.randn(100) * noise_level
    fc_with_noise = fc + np.diag(noise)
    
    X_prop.append(fc_with_noise)
X_prop = np.array(X_prop)

# %%
Y_prop = sample_df['PHC_MEM']
print(Y_prop.shape)

X_prop_transposed = np.transpose(X_prop, (1, 2, 0))
print(X_prop_transposed.shape)
# Out:
# (134,)
# (100, 100, 134)

# %%
behav_pred_pos, behav_pred_neg = run_validate(X_prop_transposed, Y_prop, 'LOO')
# Out:
# Running LOO, sub no: 0
# Running LOO, sub no: 1
# Running LOO, sub no: 2
# Running LOO, sub no: 3
# Running LOO, sub no: 4
# Running LOO, sub no: 5
# Running LOO, sub no: 6
# Running LOO, sub no: 7
# Running LOO, sub no: 8
# Running LOO, sub no: 9
# Running LOO, sub no: 10
# Running LOO, sub no: 11
# Running LOO, sub no: 12
# Running LOO, sub no: 13
# Running LOO, sub no: 14
# Running LOO, sub no: 15
# Running LOO, sub no: 16
# Running LOO, sub no: 17
# Running LOO, sub no: 18
# Running LOO, sub no: 19
# Running LOO, sub no: 20
# Running LOO, sub no: 21
# Running LOO, sub no: 22
# Running LOO, sub no: 23
# Running LOO, sub no: 24
# Running LOO, sub no: 25
# Running LOO, sub no: 26
# Running LOO, sub no: 27
# Running LOO, sub no: 28
# Running LOO, sub no: 29
# Running LOO, sub no: 30
# Running LOO, sub no: 31
# Running LOO, sub no: 32
# Running LOO, sub no: 33
# Running LOO, sub no: 34
# Running LOO, sub no: 35
# Running LOO, sub no: 36
# Running LOO, sub no: 37
# Running LOO, sub no: 38
# Running LOO, sub no: 39
# Running LOO, sub no: 40
# Running LOO, sub no: 41
# Running LOO, sub no: 42
# Running LOO, sub no: 43
# Running LOO, sub no: 44
# Running LOO, sub no: 45
# Running LOO, sub no: 46
# Running LOO, sub no: 47
# Running LOO, sub no: 48
# Running LOO, sub no: 49
# Running LOO, sub no: 50
# Running LOO, sub no: 51
# Running LOO, sub no: 52
# Running LOO, sub no: 53
# Running LOO, sub no: 54
# Running LOO, sub no: 55
# Running LOO, sub no: 56
# Running LOO, sub no: 57
# Running LOO, sub no: 58
# Running LOO, sub no: 59
# Running LOO, sub no: 60
# Running LOO, sub no: 61
# Running LOO, sub no: 62
# Running LOO, sub no: 63
# Running LOO, sub no: 64
# Running LOO, sub no: 65
# Running LOO, sub no: 66
# Running LOO, sub no: 67
# Running LOO, sub no: 68
# Running LOO, sub no: 69
# Running LOO, sub no: 70
# Running LOO, sub no: 71
# Running LOO, sub no: 72
# Running LOO, sub no: 73
# Running LOO, sub no: 74
# Running LOO, sub no: 75
# Running LOO, sub no: 76
# Running LOO, sub no: 77
# Running LOO, sub no: 78
# Running LOO, sub no: 79
# Running LOO, sub no: 80
# Running LOO, sub no: 81
# Running LOO, sub no: 82
# Running LOO, sub no: 83
# Running LOO, sub no: 84
# Running LOO, sub no: 85
# Running LOO, sub no: 86
# Running LOO, sub no: 87
# Running LOO, sub no: 88
# Running LOO, sub no: 89
# Running LOO, sub no: 90
# Running LOO, sub no: 91
# Running LOO, sub no: 92
# Running LOO, sub no: 93
# Running LOO, sub no: 94
# Running LOO, sub no: 95
# Running LOO, sub no: 96
# Running LOO, sub no: 97
# Running LOO, sub no: 98
# Running LOO, sub no: 99
# Running LOO, sub no: 100
# Running LOO, sub no: 101
# Running LOO, sub no: 102
# Running LOO, sub no: 103
# Running LOO, sub no: 104
# Running LOO, sub no: 105
# Running LOO, sub no: 106
# Running LOO, sub no: 107
# Running LOO, sub no: 108
# Running LOO, sub no: 109
# Running LOO, sub no: 110
# Running LOO, sub no: 111
# Running LOO, sub no: 112
# Running LOO, sub no: 113
# Running LOO, sub no: 114
# Running LOO, sub no: 115
# Running LOO, sub no: 116
# Running LOO, sub no: 117
# Running LOO, sub no: 118
# Running LOO, sub no: 119
# Running LOO, sub no: 120
# Running LOO, sub no: 121
# Running LOO, sub no: 122
# Running LOO, sub no: 123
# Running LOO, sub no: 124
# Running LOO, sub no: 125
# Running LOO, sub no: 126
# Running LOO, sub no: 127
# Running LOO, sub no: 128
# Running LOO, sub no: 129
# Running LOO, sub no: 130
# Running LOO, sub no: 131
# Running LOO, sub no: 132
# Running LOO, sub no: 133

# %%
res = {
    'no_files': 134, 
    'noise': 0.0001, 
    'fc_gen_method': 'compute_correlation', 
    'pearson_r_pos': pearsonr(behav_pred_pos,Y_prop)[0], 
    'pearson_r_neg': pearsonr(behav_pred_neg,Y_prop)[0],
    'spearman_rho_pos': spearmanr(behav_pred_pos,Y_prop)[0], 
    'spearman_rho_neg': spearmanr(behav_pred_neg,Y_prop)[0], 
    'r2_pos': r2_score(Y_prop, behav_pred_pos), 
    'r2_neg': r2_score(Y_prop, behav_pred_neg), 
    'mse_pos': mean_squared_error(behav_pred_pos,Y_prop),
    'mse_neg': mean_squared_error(behav_pred_neg,Y_prop)
}

# results_df = pd.concat([results_df, pd.DataFrame([res])])

# %%
res
# Out:
# {'no_files': 63,
#  'noise': 0.0001,
#  'fc_gen_method': 'normalise_correlate_fc',
#  'pearson_r_pos': -0.40155291975084756,
#  'spearman_rho_pos': -0.4642283123587598,
#  'r2_pos': -17.092593933388294,
#  'mse_pos': 0.9686637137868409}

# %% [markdown]
# ### Stratified Sampling

# %%
# Want a sample of size 50 - get 6 from each bucket

sample_eq_df = None
sample_n = 5

for i in range(n_buckets):
    bucket = buckets.get(i)
    if bucket is not None:
        f = bucket.shape[0]
        bucket_n = sample_n if f > sample_n else f
        
        random = bucket.sample(bucket_n)
        sample_eq_df = pd.concat([sample_eq_df, random])

sample_eq_df = sample_eq_df.reset_index(drop=True)
sample_eq_df.shape
# Out:
# (39, 7)

# %%
sample_eq_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   RID VISCODE2  TOTSCORE  \
# 0          1156        7074  4332     M066      1.67
# 1           821        6075  4340     M096      4.67
# 2           443        5168  1280     M120      4.67
# 3           723        5794  6076     M012      5.00
# 4          1095        6928   473     M138      4.33
#
#                                              FC_DATA  \
# 0  ../../FMRI_ADNI_DATA/fc/sub-ADNI068S4332_ses-M...
# 1  ../../FMRI_ADNI_DATA/fc/sub-ADNI068S4340_ses-M...
# 2  ../../FMRI_ADNI_DATA/fc/sub-ADNI002S1280_ses-M...
# 3  ../../FMRI_ADNI_DATA/fc/sub-ADNI014S6076_ses-M...
# 4  ../../FMRI_ADNI_DATA/fc/sub-ADNI068S0473_ses-M...
#
#                                          FC_DATA_197
# 0  ../../FMRI_ADNI_DATA/fc/sub-ADNI068S4332_ses-M...
# 1  ../../FMRI_ADNI_DATA/fc/sub-ADNI068S4340_ses-M...
# 2  ../../FMRI_ADNI_DATA/fc/sub-ADNI002S1280_ses-M...
# 3  ../../FMRI_ADNI_DATA/fc/sub-ADNI014S6076_ses-M...
# 4  ../../FMRI_ADNI_DATA/fc/sub-ADNI068S0473_ses-M...

# %%
dim_x = len(sample_eq_df)
X_strat = []

for i, file in enumerate(sample_eq_df['FC_DATA'].values):
    arr = loadmat(file)['ROI_activity'][:100, :] # get the first 100 regions
    fc = compute_correlation(arr)
    
    # Add noise along the diagonal
    noise_level = 0.0001  # Adjust this value as needed
    noise = np.random.randn(100) * noise_level
    fc_with_noise = fc + np.diag(noise)
    
    X_strat.append(fc_with_noise)
X_strat = np.array(X_strat)

# %%
Y_strat = sample_eq_df['TOTSCORE']
print(Y_strat.shape)

X_strat_transposed = np.transpose(X_strat, (1, 2, 0))
print(X_strat_transposed.shape)
# Out:
# (39,)
# (100, 100, 39)

# %%
behav_pred_pos, behav_pred_neg = run_validate(X_strat_transposed, Y_strat, 'LOO')
# Out:
# Running LOO, sub no: 0
# Running LOO, sub no: 1
# Running LOO, sub no: 2
# Running LOO, sub no: 3
# Running LOO, sub no: 4
# Running LOO, sub no: 5
# Running LOO, sub no: 6
# Running LOO, sub no: 7
# Running LOO, sub no: 8
# Running LOO, sub no: 9
# Running LOO, sub no: 10
# Running LOO, sub no: 11
# Running LOO, sub no: 12
# Running LOO, sub no: 13
# Running LOO, sub no: 14
# Running LOO, sub no: 15
# Running LOO, sub no: 16
# Running LOO, sub no: 17
# Running LOO, sub no: 18
# Running LOO, sub no: 19
# Running LOO, sub no: 20
# Running LOO, sub no: 21
# Running LOO, sub no: 22
# Running LOO, sub no: 23
# Running LOO, sub no: 24
# Running LOO, sub no: 25
# Running LOO, sub no: 26
# Running LOO, sub no: 27
# Running LOO, sub no: 28
# Running LOO, sub no: 29
# Running LOO, sub no: 30
# Running LOO, sub no: 31
# Running LOO, sub no: 32
# Running LOO, sub no: 33
# Running LOO, sub no: 34
# Running LOO, sub no: 35
# Running LOO, sub no: 36
# Running LOO, sub no: 37
# Running LOO, sub no: 38

# %%
res = {
    'no_files': 39, 
    'noise': 0.0001, 
    'fc_gen_method': 'compute_correlation', 
    'pearson_r_pos': pearsonr(behav_pred_pos,Y_strat)[0], 
    'pearson_r_neg': pearsonr(behav_pred_neg,Y_strat)[0],
    'spearman_rho_pos': spearmanr(behav_pred_pos,Y_strat)[0], 
    'spearman_rho_neg': spearmanr(behav_pred_neg,Y_strat)[0], 
    'r2_pos': r2_score(Y_strat, behav_pred_pos), 
    'r2_neg': r2_score(Y_strat, behav_pred_neg), 
    'mse_pos': mean_squared_error(behav_pred_pos,Y_strat),
    'mse_neg': mean_squared_error(behav_pred_neg,Y_strat)
}
res
# Out:
# {'no_files': 39,
#  'noise': 0.0001,
#  'fc_gen_method': 'compute_correlation',
#  'pearson_r_pos': 0.15698872895196034,
#  'pearson_r_neg': -0.10428413042131843,
#  'spearman_rho_pos': 0.14092635227392156,
#  'spearman_rho_neg': -0.07734750943769832,
#  'r2_pos': -3.7722817938565507,
#  'r2_neg': -3.0657579463697306,
#  'mse_pos': 191.68089716574656,
#  'mse_neg': 266.16074672886043}

# %% [markdown]
# ### Experiment with Sample Sizes for ADAS-Cog 11

# %%
ADAS_DATA_ALL = '../data/ADAS_ADNIGO23_17Apr2024_FILTERED_wfiles.csv'
df_all = pd.read_csv(ADAS_DATA_ALL)
df_all.shape
# Out:
# (1340, 5)

# %%
plt.figure(figsize=(8, 6))
plt.hist(df_all['TOTSCORE'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of ADAS-Cog Scores in Participants')
plt.xlabel('ADAS-Cog Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.axis('on')
# plt.savefig('../data/adas_score_dist_20.png')

plt.show()

# %%
# Define the number of buckets
n_buckets = 10

# Define the bins for splitting the column into buckets
bins = pd.cut(df_all['TOTSCORE'], bins=n_buckets, labels=False)

# %%
bins
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 1335    0
# 1336    2
# 1337    0
# 1338    3
# 1339    0
# Name: TOTSCORE, Length: 1340, dtype: int64

# %%
buckets = {i: group for i, group in df_all.groupby(bins)}

for i in range(n_buckets):
    bucket = buckets.get(i)
    if bucket is not None:
        print(f"Bucket {i}:")
        print(bucket.shape)
# Out:
# Bucket 0:
# (523, 5)
# Bucket 1:
# (493, 5)
# Bucket 2:
# (174, 5)
# Bucket 3:
# (83, 5)
# Bucket 4:
# (41, 5)
# Bucket 5:
# (10, 5)
# Bucket 6:
# (8, 5)
# Bucket 7:
# (5, 5)
# Bucket 9:
# (3, 5)

# %%
# Stratified Sampling
# Want a sample of size 50 - get 5 from each bucket

# sample_eq_df = None
# sample_n = 6

# for i in range(n_buckets):
#     bucket = buckets.get(i)
#     if bucket is not None:
#         f = bucket.shape[0]
#         bucket_n = sample_n if f > sample_n else f
        
#         random = bucket.sample(bucket_n)
#         sample_eq_df = pd.concat([sample_eq_df, random])

# sample_eq_df = sample_eq_df.reset_index(drop=True)
# sample_eq_df.shape

# Proportional sampling - get 10%

sample_df = None
total_sample = 0

for i in range(n_buckets):
    bucket = buckets.get(i)
    if bucket is not None:
        f = bucket.shape[0]
        sample_n = 1 if f * 0.1 < 1 else round(f * 0.1)
        print(sample_n)
        
        random = bucket.sample(sample_n)
        sample_df = pd.concat([sample_df, random])

sample_df = sample_df.reset_index(drop=True)
sample_df.shape
# Out:
# 52
# 49
# 17
# 8
# 4
# 1
# 1
# 1
# 1
# (134, 5)

# %%
dim_x = len(sample_df)
X_prop = []

for i, file in enumerate(sample_df['FC_DATA'].values):
    arr = loadmat(file)['ROI_activity'][:100, :] # get the first 100 regions
    fc = compute_correlation(arr)
    
    # Add noise along the diagonal
    noise_level = 0.0001  # Adjust this value as needed
    noise = np.random.randn(100) * noise_level
    fc_with_noise = fc + np.diag(noise)
    
    X_prop.append(fc_with_noise)
X_prop = np.array(X_prop)

Y_prop = sample_df['TOTSCORE']
print(Y_prop.shape)

X_prop_transposed = np.transpose(X_prop, (1, 2, 0))
print(X_prop_transposed.shape)
# Out:
# (134,)
# (100, 100, 134)

# %%
behav_pred_pos, behav_pred_neg = run_validate(X_prop_transposed, Y_prop, 'LOO')

# %%
res = {
    'no_files': 134, 
    'noise': 0.0001, 
    'fc_gen_method': 'compute_correlation', 
    'pearson_r_pos': pearsonr(behav_pred_pos,Y_prop)[0], 
    'pearson_r_neg': pearsonr(behav_pred_neg,Y_prop)[0],
    'spearman_rho_pos': spearmanr(behav_pred_pos,Y_prop)[0], 
    'spearman_rho_neg': spearmanr(behav_pred_neg,Y_prop)[0], 
    'r2_pos': r2_score(behav_pred_pos,Y_prop), 
    'r2_neg': r2_score(behav_pred_neg,Y_prop), 
    'mse_pos': mean_squared_error(behav_pred_pos,Y_prop),
    'mse_neg': mean_squared_error(behav_pred_neg,Y_prop)
}
res
# Out:
# {'no_files': 134,
#  'noise': 0.0001,
#  'fc_gen_method': 'compute_correlation',
#  'pearson_r_pos': 0.12093623752690097,
#  'spearman_rho_pos': 0.11000444901836241,
#  'r2_pos': -14.254429822692055,
#  'mse_pos': 68.09069997573967}
